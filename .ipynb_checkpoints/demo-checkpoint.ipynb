# %%
import os
import torch
import argparse
import scripts.datasets as datasets
import numpy as np
import random
import seaborn as sns
# %matplotlib inline
from PIL import Image
import matplotlib.pyplot as plt
from scripts.models.fusion_vgg import *
from scripts.models.unet import *

from scripts.utils.imgUtils import im_to_numpy
import imageio
import time
from skimage.metrics import structural_similarity as compare_ssim
from skimage.metrics import peak_signal_noise_ratio as compare_psnr
from skimage.metrics import mean_squared_error as compare_mse
from matplotlib.pyplot import MultipleLocator
import cv2
from thop import profile, clever_format
class objectview(object):
    def __init__(self, *args, **kwargs):
        d = dict(*args, **kwargs)
        self.__dict__ = d

# with open("test_labels.txt") as f:
#     classes = [line.split(',')[0].strip() for line in f.readlines()]

def save_image(image_numpy, image_path, aspect_ratio=1.0):
    """Save a numpy image to the disk

    Parameters:
        image_numpy (numpy array) -- input numpy array
        image_path (str)          -- the path of the image
    """

    image_pil = Image.fromarray(image_numpy)
    h, w, _ = image_numpy.shape

    if aspect_ratio > 1.0:
        image_pil = image_pil.resize((h, int(w * aspect_ratio)), Image.BICUBIC)
    if aspect_ratio < 1.0:
        image_pil = image_pil.resize((int(h / aspect_ratio), w), Image.BICUBIC)
    image_pil.save(image_path,quality=200) #added by Mia (quality)

    
data_config  = objectview({'input_size':256,
                            'limited_dataset':0,
                            'normalized_input':False,
                            'data_augumentation':False,
                            'base_dir':'/home/ipprlab/datasets/',
                            'withLabel':'True',
                            'load_size':286,
                            'crop_size':256,
                            'data':'HFlickr'})


val_loader = torch.utils.data.DataLoader(datasets.HCOCO('val', data_config), batch_size=1, shuffle=False,
                                             num_workers=1, pin_memory=False, drop_last=True)

res=256
sq = vgg16(pretrained=True)
model = CreateNetFusion_vgg(sq, stack=True).cuda()
# sq = squeezenet1_1(pretrained=True)
# model = CreateNetFusionV3(sq, stack=True).cuda()
# model_class = squeezenet1_1(pretrained=True).cuda()
model.load_state_dict(torch.load('/home/ipprlab/projects/xharm/vgg_con.tar')['state_dict'])

def CF(img, param, pieces):
    
    # bs x 3 x 1 x 1 x 64
    color_curve_sum = torch.sum(param, 4) + 1e-30
    total_image = img * 0

    for i in range(pieces):
        total_image += torch.clamp(img - 1.0 * i /pieces, 0, 1.0 / pieces) * param[:, :, :, :, i]
    total_image *= pieces/ color_curve_sum
    return total_image


psnrs = []
mses = []
start = torch.cuda.Event(enable_timing=True)
end = torch.cuda.Event(enable_timing=True)


plt.figure(figsize=(25,5))

with torch.no_grad():
    for i, batches in enumerate(val_loader):
        print(i)
        inputs = batches['composite_images'].to('cuda')
        target = batches['real_images'].to('cuda')
        mask = batches['mask'].to('cuda')
        fore = batches["fore_images"].to('cuda')  #: self.trans(thumb_foreground),
        foremask = batches["fore_mask"].to('cuda')  # "fore_mask":self.trans(thumb_mask),
        label = batches['label']
        ori_img = batches["ori_img"].to('cuda')
        cv2_img = batches["cv2_img"].to('cuda')
        ori_mask = batches["ori_mask"].to('cuda')
        ori_target = batches["ori_tar"].to('cuda')
        # print(label.shape)
        label_oh = torch.zeros(1, 5).scatter_(1, label.view(label.shape[0], 1), 1).to(
            torch.float32).to('cuda')
#          if self.withLabel:
#                     label_oh = label_oh
#                 else:
#                     label_oh = None
#         print(label_oh)
        feeded = torch.cat([inputs, mask], dim=1).to('cuda')
        fore = torch.cat([fore, foremask], dim=1).to('cuda')
        start.record()
        outputs, param1, param2 = model(ori_img, feeded, fore, label_oh, True)
        end.record()
        torch.cuda.synchronize()
#         macs, params = profile(model, inputs=(ori_img, feeded, fore, label_oh, True))
#         macs, params = clever_format([macs, params], "%.3f")
        outputs = outputs if type(outputs) == type(()) else [outputs]
#         print(outputs[0].shape, cv2_img.shape)
#         cv2_img = torch.tensor(cv2_img)
#         cv2_tar = torch.tensor(ori_target)
#         cv2_mask = torch.tensor(ori_mask)
#         imageio.imwrite('/home/ipprlab/projects/xharm/Figs/hr/inputs/2048.jpg' , cv2_img.squeeze(0).permute(1, 2, 0).cpu().numpy())
#         imageio.imwrite('/home/ipprlab/projects/xharm/Figs/hr/target/2048.jpg' , cv2_tar.squeeze(0).permute(1, 2, 0).cpu().numpy())
#         imageio.imwrite('/home/ipprlab/projects/xharm/Figs/hr/masks/2048.jpg' , cv2_mask.squeeze(0).permute(1, 2, 0).cpu().numpy())
        imfinal1 = outputs[0] * mask + target * (1 - mask)
#         imfinal = outputs[0] * ori_mask + ori_target * (1 - ori_mask)
        imfinal2 = outputs[1] * mask + target * (1 - mask)



#                    # recover the image to 255
#         print(imfinal.shape)
#         inputs = inputs.squeeze(0).permute(1, 2, 0).cpu().numpy()
#         imfinal = im_to_numpy(torch.clamp(imfinal[0] * 255, min=0.0, max=255.0)).astype(np.uint8)
#         target = im_to_numpy(torch.clamp(ori_target[0] * 255, min=0.0, max=255.0)).astype(np.uint8)


        imall = torch.cat([inputs,mask.repeat(1,3,1,1),imfinal1,imfinal2,target],dim=3)
        imfinal = im_to_numpy(torch.clamp(imall[0] * 255, min=0.0, max=255.0)).astype(np.uint8)
        
        plt.imshow(imfinal)
# Out:
# loading validation file...
# True
# total Dataset of HAdobe5k is :s  2160
# train: 2160 mask: 2160 anno: 2160
# stack: True
# 64
# 64
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): ReLU(inplace=True)
#   (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (3): ReLU(inplace=True)
#   (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (6): ReLU(inplace=True)
#   (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (8): ReLU(inplace=True)
#   (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (11): ReLU(inplace=True)
#   (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (13): ReLU(inplace=True)
#   (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (15): ReLU(inplace=True)
#   (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (18): ReLU(inplace=True)
#   (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (20): ReLU(inplace=True)
#   (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (22): ReLU(inplace=True)
#   (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (25): ReLU(inplace=True)
#   (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (27): ReLU(inplace=True)
#   (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (29): ReLU(inplace=True)
# )
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-46e99f35a70e> in <module>
#      90
#      91 with torch.no_grad():
# ---> 92     for i, batches in enumerate(val_loader):
#      93         print(i)
#      94         inputs = batches['composite_images'].to('cuda')
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     433         if self._sampler_iter is None:
#     434             self._reset()
# --> 435         data = self._next_data()
#     436         self._num_yielded += 1
#     437         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1066
#    1067             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1068             idx, data = self._get_data()
#    1069             self._tasks_outstanding -= 1
#    1070             if self._dataset_kind == _DatasetKind.Iterable:
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1032         else:
#    1033             while True:
# -> 1034                 success, data = self._try_get_data()
#    1035                 if success:
#    1036                     return data
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     870         #   (bool: whether successfully get data, any: data if successful else None)
#     871         try:
# --> 872             data = self._data_queue.get(timeout=timeout)
#     873             return (True, data)
#     874         except Exception as e:
#
# ~/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py in get(self, block, timeout)
#     102                 if block:
#     103                     timeout = deadline - time.monotonic()
# --> 104                     if not self._poll(timeout):
#     105                         raise Empty
#     106                 elif not self._poll():
#
# ~/anaconda3/envs/py36/lib/python3.6/multiprocessing/connection.py in poll(self, timeout)
#     255         self._check_closed()
#     256         self._check_readable()
# --> 257         return self._poll(timeout)
#     258
#     259     def __enter__(self):
#
# ~/anaconda3/envs/py36/lib/python3.6/multiprocessing/connection.py in _poll(self, timeout)
#     412
#     413     def _poll(self, timeout):
# --> 414         r = wait([self], timeout)
#     415         return bool(r)
#     416
#
# ~/anaconda3/envs/py36/lib/python3.6/multiprocessing/connection.py in wait(object_list, timeout)
#     909
#     910             while True:
# --> 911                 ready = selector.select(timeout)
#     912                 if ready:
#     913                     return [key.fileobj for (key, events) in ready]
#
# ~/anaconda3/envs/py36/lib/python3.6/selectors.py in select(self, timeout)
#     374             ready = []
#     375             try:
# --> 376                 fd_event_list = self._poll.poll(timeout)
#     377             except InterruptedError:
#     378                 return ready
#
# KeyboardInterrupt:
