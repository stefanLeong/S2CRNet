# %%
import os
import torch
import argparse
import scripts.datasets as datasets
import numpy as np
import random
import seaborn as sns
# %matplotlib inline
from PIL import Image
import matplotlib.pyplot as plt
from scripts.models.fusion_vgg import *
from scripts.models.unet import *
from scripts.models.squeezeNet import *
from scripts.utils.imgUtils import im_to_numpy
import imageio
import time
from skimage.metrics import structural_similarity as compare_ssim
from skimage.metrics import peak_signal_noise_ratio as compare_psnr
from skimage.metrics import mean_squared_error as compare_mse
from matplotlib.pyplot import MultipleLocator
import cv2
from thop import profile, clever_format
class objectview(object):
    def __init__(self, *args, **kwargs):
        d = dict(*args, **kwargs)
        self.__dict__ = d

# with open("test_labels.txt") as f:
#     classes = [line.split(',')[0].strip() for line in f.readlines()]

def save_image(image_numpy, image_path, aspect_ratio=1.0):
    """Save a numpy image to the disk

    Parameters:
        image_numpy (numpy array) -- input numpy array
        image_path (str)          -- the path of the image
    """

    image_pil = Image.fromarray(image_numpy)
    h, w, _ = image_numpy.shape

    if aspect_ratio > 1.0:
        image_pil = image_pil.resize((h, int(w * aspect_ratio)), Image.BICUBIC)
    if aspect_ratio < 1.0:
        image_pil = image_pil.resize((int(h / aspect_ratio), w), Image.BICUBIC)
    image_pil.save(image_path,quality=200) #added by Mia (quality)

    
data_config  = objectview({'input_size':256,
                            'limited_dataset':0,
                            'normalized_input':False,
                            'data_augumentation':False,
                            'base_dir':'/home/ipprlab/datasets/',
                            'withLabel':'True',
                            'load_size':286,
                            'crop_size':256,
                            'data':'Hday2night','hr_size':256
                          })


val_loader = torch.utils.data.DataLoader(datasets.HCOCO('val', data_config), batch_size=1, shuffle=False,
                                             num_workers=1, pin_memory=False, drop_last=True)

# res=256
# sq = vgg16(pretrained=True)
# model = CreateNetFusion_vgg(sq, stack=True).cuda()

sq = squeezenet1_1(pretrained=True)
# model = CreateNetFusionV3(sq, stack=True).cuda()
model_class = squeezenet1_1(pretrained=True).cuda()
# model.load_state_dict(torch.load('/home/ipprlab/projects/xharm/vgg_con.tar')['state_dict'])

def CF(img, param, pieces):
    
    # bs x 3 x 1 x 1 x 64
    color_curve_sum = torch.sum(param, 4) + 1e-30
    total_image = img * 0

    for i in range(pieces):
        total_image += torch.clamp(img - 1.0 * i /pieces, 0, 1.0 / pieces) * param[:, :, :, :, i]
    total_image *= pieces/ color_curve_sum
    return total_image


psnrs = []
mses = []
start = torch.cuda.Event(enable_timing=True)
end = torch.cuda.Event(enable_timing=True)

label_file = open('Hday2night_test_sqlabels.txt', 'w+')

with torch.no_grad():
    for i, batches in enumerate(val_loader):
#         if batches['name'][0] != 'a3630_1_5.jpg':
#             continue
        inputs = batches['composite_images'].to('cuda')
        target = batches['real_images'].to('cuda')
        mask = batches['mask'].to('cuda')
        fore = batches["fore_images"].to('cuda')  #: self.trans(thumb_foreground),
        foremask = batches["fore_mask"].to('cuda')  # "fore_mask":self.trans(thumb_mask),
        label = batches['label']
        ori_img = batches["ori_img"].to('cuda')
        cv2_img = batches["cv2_img"].to('cuda')
        ori_mask = batches["ori_mask"].to('cuda')
        ori_target = batches["ori_tar"].to('cuda')
        # print(label.shape)
        label_oh = torch.zeros(1, 5).scatter_(1, label.view(label.shape[0], 1), 1).to(
            torch.float32).to('cuda')
#          if self.withLabel:
#                     label_oh = label_oh
#                 else:
#                     label_oh = None
#         print(label_oh)
        sq_prop = model_class(fore).argmax()
        macs, params = profile(model_class, inputs=(fore))
        macs, params = clever_format([macs, params], "%.3f")
        
        # print(macs)
        if sq_prop <= 397:
            sq_class = 'animal'
            label = '1'
        elif sq_prop in [724,981,982,983]:
            sq_class = 'person'
            label = '0'
        elif sq_prop in [998,987,969,967,976,965,964,963,962,961,960,959,927,928,929,930,931,932,933,934,925,924,907,773,737,441,440]:
            sq_class = 'food'
            label = '2'
        elif sq_prop in [408,407,436,444,450,468,517,537,555,561,569,573,575,581,586,595,603,609,612,621,626,654,656,
                         661,665,670,671,675,690,705,717,730,734,751,757,779,802,803,817,829,847,856,864,866,867,870,874,880]:
            sq_class = 'vehicle'
            label = '3'
        else:
            sq_class = 'others'
            label = '4'
        print(batches['name'][0], sq_class, label)
        label_file.write(batches['name'][0] + ' ' + sq_class + ' ' + label + '\n')
# Out:
# loading validation file...
# True
# total Dataset of Hday2night is :s  133
# train: 133 mask: 133 anno: 133
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.activation.ReLU'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.pooling.MaxPool2d'>.
# [WARN] Cannot find rule for <class 'scripts.models.squeezeNet.Fire'>. Treat it as zero Macs and zero Params.
# [WARN] Cannot find rule for <class 'torch.nn.modules.container.Sequential'>. Treat it as zero Macs and zero Params.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.dropout.Dropout'>.
# [INFO] Register count_adap_avgpool() for <class 'torch.nn.modules.pooling.AdaptiveAvgPool2d'>.
# [WARN] Cannot find rule for <class 'scripts.models.squeezeNet.SqueezeNet'>. Treat it as zero Macs and zero Params.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-2-e20729830a7a> in <module>
#     113 #         print(label_oh)
#     114         # sq_prop = model_class(fore).argmax()
# --> 115         macs, params = profile(model_class, inputs=(fore))
#     116         macs, params = clever_format([macs, params], "%.3f")
#     117
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/thop/profile.py in profile(model, inputs, custom_ops, verbose)
#     186
#     187     with torch.no_grad():
# --> 188         model(*inputs)
#     189
#     190     def dfs_count(module: nn.Module, prefix="\t") -> (int, int):
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/projects/xharm/scripts/models/squeezeNet.py in forward(self, x)
#      92
#      93     def forward(self, x: torch.Tensor) -> torch.Tensor:
# ---> 94         x = self.features(x)
#      95         x = self.classifier(x)
#      96         return torch.flatten(x, 1)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     421
#     422     def forward(self, input: Tensor) -> Tensor:
# --> 423         return self._conv_forward(input, self.weight)
#     424
#     425 class Conv3d(_ConvNd):
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight)
#     418                             _pair(0), self.dilation, self.groups)
#     419         return F.conv2d(input, weight, self.bias, self.stride,
# --> 420                         self.padding, self.dilation, self.groups)
#     421
#     422     def forward(self, input: Tensor) -> Tensor:
#
# RuntimeError: Expected 4-dimensional input for 4-dimensional weight [64, 3, 3, 3], but got 3-dimensional input of size [3, 256, 256] instead
