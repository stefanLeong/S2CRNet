# %%
import os
import torch
import argparse
import scripts.datasets as datasets
import scripts.machine as machines
import numpy as np
import random
import seaborn as sns
# %matplotlib inline
from PIL import Image
import matplotlib.pyplot as plt
from scripts.models.fusion_vgg import *
from scripts.utils.imgUtils import im_to_numpy
import imageio
import time
from skimage.metrics import structural_similarity as compare_ssim
from skimage.metrics import peak_signal_noise_ratio as compare_psnr
from skimage.metrics import mean_squared_error as compare_mse
from matplotlib.pyplot import MultipleLocator
import cv2
from thop import profile, clever_format
class objectview(object):
    def __init__(self, *args, **kwargs):
        d = dict(*args, **kwargs)
        self.__dict__ = d

# with open("test_labels.txt") as f:
#     classes = [line.split(',')[0].strip() for line in f.readlines()]
# #     print(classes)

def save_image(image_numpy, image_path, aspect_ratio=1.0):
    """Save a numpy image to the disk

    Parameters:
        image_numpy (numpy array) -- input numpy array
        image_path (str)          -- the path of the image
    """

    image_pil = Image.fromarray(image_numpy)
    h, w, _ = image_numpy.shape

    if aspect_ratio > 1.0:
        image_pil = image_pil.resize((h, int(w * aspect_ratio)), Image.BICUBIC)
    if aspect_ratio < 1.0:
        image_pil = image_pil.resize((int(h / aspect_ratio), w), Image.BICUBIC)
    image_pil.save(image_path,quality=200) #added by Mia (quality)

    
data_config  = objectview({'input_size':256,
                            'limited_dataset':0,
                            'normalized_input':False,
                            'data_augumentation':False,
                            'base_dir':'/home/ipprlab/datasets/',
                            'withLabel':'True',
                            'load_size':286,
                            'crop_size':256,
                            'data':'DIH'})


val_loader = torch.utils.data.DataLoader(datasets.RCOCO('val', data_config), batch_size=1, shuffle=False,
                                             num_workers=1, pin_memory=False, drop_last=True)

res=256
# sq = squeezenet1_1(pretrained=True)
# model = CreateNetFusionV3(sq, stack=True).cuda()
sq = vgg16(pretrained=True)
model = CreateNetFusion_vgg(sq, stack=True).cuda()
# model_class = squeezenet1_1(pretrained=True).cuda()
model.load_state_dict(torch.load('/home/ipprlab/projects/xharm/vgg_con.tar')['state_dict'])

def CF(img, param, pieces):
    
    # bs x 3 x 1 x 1 x 64
    color_curve_sum = torch.sum(param, 4) + 1e-30
    total_image = img * 0

    for i in range(pieces):
        total_image += torch.clamp(img - 1.0 * i /pieces, 0, 1.0 / pieces) * param[:, :, :, :, i]
    total_image *= pieces/ color_curve_sum
    return total_image


psnrs = []
mses = []
start = torch.cuda.Event(enable_timing=True)
end = torch.cuda.Event(enable_timing=True)


# norm = MeanShift([0.485, 0.456, 0.406], [0.229, 0.224, 0.225], norm=True).cuda()

with torch.no_grad():
    for i, batches in enumerate(val_loader):
#         print(batches["name"])
#         if batches["name"][0] != "test_32.png":
#             continue
        inputs = batches['composite_images'].to('cuda')
#         target = batches['real_images'].to('cuda')
        mask = batches['mask'].to('cuda')
        fore = batches["fore_images"].to('cuda')  #: self.trans(thumb_foreground),
        foremask = batches["fore_mask"].to('cuda')  # "fore_mask":self.trans(thumb_mask),
        label = batches['label']
        ori_img = batches["ori_img"].to('cuda')
        cv2_img = batches["cv2_img"].to('cuda')
#         ori_mask = batches["ori_mask"].to('cuda')
#         ori_target = batches["ori_tar"].to('cuda')
        # print(label.shape)
        label_oh = torch.zeros(1, 5).scatter_(1, label.view(label.shape[0], 1), 1).to(
            torch.float32).to('cuda')
#          if self.withLabel:
#                     label_oh = label_oh
#                 else:
#                     label_oh = None
#         print(label_oh)
        feeded = torch.cat([inputs, mask], dim=1).to('cuda')
        fore = torch.cat([fore, foremask], dim=1).to('cuda')
        start.record()
        outputs, param1, param2 = model(ori_img, feeded, fore, label_oh, True)
        end.record()
        torch.cuda.synchronize()
#         macs, params = profile(model, inputs=(ori_img, feeded, fore, label_oh, True))
#         macs, params = clever_format([macs, params], "%.3f")
        print(cv2_img.shape)
        outputs = outputs if type(outputs) == type(()) else [outputs]
        print(outputs[0].shape, cv2_img.shape)
        cv2_img = torch.tensor(cv2_img)
        
        imfinal = outputs[0] * mask + cv2_img * (1 - mask)


#                    # recover the image to 255
        print(inputs.shape)
        inputs = inputs.squeeze(0).permute(1, 2, 0).cpu().numpy()
        imfinal = im_to_numpy(torch.clamp(imfinal[0] * 255, min=0.0, max=255.0)).astype(np.uint8)
#             target = im_to_numpy(torch.clamp(target[0] * 255, min=0.0, max=255.0)).astype(np.uint8)
          
#             psnr = compare_psnr(imfinal, target, data_range=imfinal.max() - imfinal.min())
#             ssim = compare_ssim(imfinal, target, multichannel=True)
#             mse = compare_mse(imfinal, target)
#             imageio.imwrite('test'+ '/ablation/' + batches['name'][0], img_show)
        print(batches["img_url"])
#             imageio.imwrite('/home/ipprlab/projects/xharm/test/multiscale/HAdobe5k/inputs/'  + 'ori_' + batches['name'][0], inputs)
            
#         imageio.imwrite('/home/ipprlab/projects/xharm/test/DIH_ori/'  + batches['name'][0], cv2_img.squeeze(0).permute(1, 2, 0).cpu().numpy())

#         imageio.imwrite('/home/ipprlab/projects/xharm/test/DIH_vgg/' + batches['name'][0], imfinal)
        imageio.imwrite('/home/ipprlab/projects/xharm/test/DIH_mask/' + batches['name'][0], mask.squeeze(0).permute(1, 2, 0).cpu().numpy())
#             print('PSNR:', psnr)
            
#         cv2.imshow('img',img_show)
#         cv2.waitKey()
#         print(w_list)
# Out:
# loading validation file...
# True
# total Dataset of DIH is :  99
# train: 99 mask: 99 anno: 0
# stack: True
# 64
# 64
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): ReLU(inplace=True)
#   (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (3): ReLU(inplace=True)
#   (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (6): ReLU(inplace=True)
#   (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (8): ReLU(inplace=True)
#   (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (11): ReLU(inplace=True)
#   (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (13): ReLU(inplace=True)
#   (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (15): ReLU(inplace=True)
#   (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (18): ReLU(inplace=True)
#   (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (20): ReLU(inplace=True)
#   (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (22): ReLU(inplace=True)
#   (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (25): ReLU(inplace=True)
#   (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (27): ReLU(inplace=True)
#   (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (29): ReLU(inplace=True)
# )
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_40.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test22_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_12.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test01_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test06_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_44.png']
# /home/ipprlab/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:125: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_14.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test44_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_39.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_49.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_08.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test16_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_33.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test03_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test20_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_45.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_01.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test47_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test19_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_07.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_43.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test31_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test39_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test45_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test32_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test14_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test08_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test29_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_11.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test05_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test17_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_35.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_51.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test07_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_23.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_38.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test37_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_21.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test48_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test46_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_09.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_24.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test30_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test34_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_47.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test11_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_41.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_20.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_06.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_04.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test33_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test09_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test43_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test28_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_25.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_37.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_10.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_15.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_27.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_28.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test12_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test15_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test35_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test10_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_22.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_05.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_17.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test23_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test38_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_16.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test26_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_29.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test04_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_34.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_42.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test21_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test27_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test02_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_50.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_13.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test40_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_02.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test25_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_36.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_26.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_48.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_03.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test41_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test24_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_31.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_30.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_46.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test18_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_19.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_32.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test36_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test13_Su.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test_18.png']
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256]) torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# ['/home/ipprlab/datasets/DIH/composite_images/test42_Su.png']
