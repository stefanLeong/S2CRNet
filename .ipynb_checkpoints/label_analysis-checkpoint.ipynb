# %%
import os
import torch
import argparse
import scripts.datasets as datasets
import scripts.machine as machines
import numpy as np
import random
# %matplotlib inline
from PIL import Image
import matplotlib.pyplot as plt
from scripts.models.unet import *
from scripts.models.unet import CreateNetFusionV3
from scripts.utils.imgUtils import im_to_numpy
import imageio
import time
from skimage.metrics import structural_similarity as compare_ssim
from skimage.metrics import peak_signal_noise_ratio as compare_psnr
from skimage.metrics import mean_squared_error as compare_mse
import cv2
import matplotlib

from thop import profile, clever_format
class objectview(object):
    def __init__(self, *args, **kwargs):
        d = dict(*args, **kwargs)
        self.__dict__ = d

# with open("test_labels.txt") as f:
#     classes = [line.split(',')[0].strip() for line in f.readlines()]
# #     print(classes)

data_config  = objectview({'input_size':256,
                            'limited_dataset':0,
                            'normalized_input':False,
                            'data_augumentation':False,
                            'base_dir':'/home/ipprlab/datasets/',
                            'preprocess':'scale_width_and_crop',
                            'withLabel':'True',
                            'load_size':286,
                            'crop_size':256,
                            'data':'ABS'})


val_loader = torch.utils.data.DataLoader(datasets.HCOCO('val', data_config), batch_size=1, shuffle=False,
                                             num_workers=0, pin_memory=False, drop_last=True)

res=256
sq = squeezenet1_1(pretrained=True)
model = CreateNetFusionV3(sq, stack=True).cuda()
# model_class = squeezenet1_1(pretrained=True).cuda()
model.load_state_dict(torch.load('/home/ipprlab/projects/xharm/nomask.tar')['state_dict'])

def CF(img, param, pieces):
    
    # bs x 3 x 1 x 1 x 64
    color_curve_sum = torch.sum(param, 4) + 1e-30
    total_image = img * 0

    for i in range(pieces):
        total_image += torch.clamp(img - 1.0 * i /pieces, 0, 1.0 / pieces) * param[:, :, :, :, i]
    total_image *= pieces/ color_curve_sum
    return total_image


psnrs = []
mses = []
start = torch.cuda.Event(enable_timing=True)
end = torch.cuda.Event(enable_timing=True)


norm = MeanShift([0.485, 0.456, 0.406], [0.229, 0.224, 0.225], norm=True).cuda()

with torch.no_grad():
    for i, batches in enumerate(val_loader):
        if i != 6:
            continue
        inputs = batches['composite_images'].to('cuda')
        target = batches['real_images'].to('cuda')
        mask = batches['mask'].to('cuda')
        fore = batches["fore_images"].to('cuda')  #: self.trans(thumb_foreground),
        foremask = batches["fore_mask"].to('cuda')  # "fore_mask":self.trans(thumb_mask),
        label = batches['label']
        ori_img = batches["ori_img"].to('cuda')
        cv2_img = batches["cv2_img"].to('cuda')
#         ori_mask = batches["ori_mask"].to('cuda')
        # print(label.shape)
        label_oh = torch.zeros(1, 5).scatter_(1, label.view(label.shape[0], 1), 1).to(
            torch.float32).to('cuda')
#         if self.withLabel:
#             label_oh = label_oh
#         else:
#             label_oh = None
        
#         print(label.shape, label_1)
#         print(label)
        feeded = torch.cat([inputs, mask], dim=1).to('cuda')
        fore = torch.cat([fore, foremask], dim=1).to('cuda')
       
        outputs, param1, param2 = model(ori_img, feeded, fore, label_oh, True)
        final = outputs[0] * mask + inputs * (1-mask)
        imall = torch.cat([inputs,mask.repeat(1,3,1,1),final,target],dim=3)
        imfinal = im_to_numpy(torch.clamp(imall[0] * 255, min=0.0, max=255.0)).astype(np.uint8)
        plt.imshow(imfinal)
        final = outputs[0] * mask + inputs * (1-mask)
      
        imageio.imwrite('/home/ipprlab/projects/xharm/Figs/Encoder/' + batches['name'][0] + 'outputs_nomask' + '.jpg', final.squeeze(0).cpu().permute(1, 2, 0).numpy())
#         imageio.imwrite('/home/ipprlab/projects/xharm/Figs/Encoder/' + batches['name'][0] + 'inputs' + '.jpg', inputs.squeeze(0).cpu().permute(1, 2, 0).numpy())
#         imageio.imwrite('/home/ipprlab/projects/xharm/Figs/Encoder/' + batches['name'][0] + 'mask' + '.jpg', mask.squeeze(0).cpu().permute(1, 2, 0).numpy())



#         macs, params = profile(model, inputs=(ori_img, feeded, fore, label_oh, True))
#         macs, params = clever_format([macs, params], "%.3f")
#         print(macs, params, start.elapsed_time(end))

#         outputs = outputs if type(outputs) == type(()) else [outputs]

       
      
#         if i % 20 == 0:
#             print(batches["name"])

#             plt.figure()
#             p1 = param1.view(1,3,1,1,64).cpu()
#             xx = np.arange(0,1,1/64)
#             #         plt.ylim(-7, 7)
#             plt.ylim(0, 1)
#             plt.xlim(0, 1)
#             yy = torch.from_numpy(xx).view(1,1,1,64).repeat(1,3,1,1)
#             yy = CF(yy,p1,64)
#             plt.plot(xx,yy[0,0,0],'r')
#             plt.plot(xx,yy[0,1,0],'g')
#             plt.plot(xx,yy[0,2,0],'b')
#             plt.show()
        superCats = ['Person', 'Animal', 'Food', 'Vehicle', 'Others']
        if  i == 99:
            print(batches["name"])
            print(superCats[label])
            imageio.imwrite('/home/ipprlab/projects/xharm/Figs/Label_analysis/' + batches['name'][0] + 'outputs_' + '.jpg', cv2_img.squeeze(0).cpu().permute(1, 2, 0).numpy())
            imageio.imwrite('/home/ipprlab/projects/xharm/Figs/Label_analysis/' + batches['name'][0] + 'mask'+ '.jpg', mask.squeeze(0).cpu().permute(1, 2, 0).numpy())
            imageio.imwrite('/home/ipprlab/projects/xharm/Figs/Label_analysis/' + batches['name'][0] + '.jpg', inputs.squeeze(0).cpu().permute(1, 2, 0).numpy())

           
#             fig,ax = plt.subplots(1,5, sharex = 'col', figsize=(35, 5), dpi=85)
            for i in range(0, 5):
                
                label = torch.tensor([i])
        #                 print(label)
                label_oh = torch.zeros(1, 5).scatter_(1, label.view(label.shape[0], 1), 1).to(torch.float32).to('cuda')
                feeded = torch.cat([inputs, mask], dim=1).to('cuda')
        #             fore_in = torch.cat([fore, foremask], dim=1).to('cuda')
        #                 print(ori_img.shape, feeded.shape, fore.shape)
                outputs, param1, param2 = model(ori_img, feeded, fore, label_oh, True)
                final = outputs[0] * mask + inputs * (1-mask)
                
                imageio.imwrite('/home/ipprlab/projects/xharm/Figs/Label_analysis/' + batches['name'][0] + 'outputs_' + superCats[i]+ '.jpg', final.squeeze(0).cpu().permute(1, 2, 0).numpy())
#                 ax1 = ax[i]
#                 ax1.set_ylim([0, 1])
#                 ax1.set_xlim([0, 1])
#                 p1 = param1.view(1,3,1,1,64).cpu()
#                 xx = np.arange(0,1,1/64)
#                 #         plt.ylim(-7, 7)

#                 yy = torch.from_numpy(xx).view(1,1,1,64).repeat(1,3,1,1)
#                 yy = CF(yy,p1,64)
#                 ax1.plot(xx,yy[0,0,0],'r')
#                 ax1.plot(xx,yy[0,1,0],'g')
#                 ax1.plot(xx,yy[0,2,0],'b')
#         #                 ax1.legend()
        
#                 ax1.set_title('Style Curve of Label %s'% (superCats[i]))
#                 ax1 = ax[i]
#                 plt.style.use('nature')
                plt.figure()
               
                plt.ylim([0, 1])
                plt.xlim([0, 1])
                plt.tick_params(labelsize=20)
                p1 = param1.view(1,3,1,1,64).cpu()
                xx = np.arange(0,1,1/64)
                #         plt.ylim(-7, 7)

                yy = torch.from_numpy(xx).view(1,1,1,64).repeat(1,3,1,1)
                yy = CF(yy,p1,64)
                plt.plot(xx,yy[0,0,0],'r', label='R')
                plt.plot(xx,yy[0,1,0],'g', label='G')
                plt.plot(xx,yy[0,2,0],'b', label='B')
        #                 ax1.legend()
        
#                 plt.title('Style Curves of Label \'%s\''% (superCats[i]))
        #         plt.grid()
        #             ax2 = ax[1][i]
        #             p2 = param2.view(1,3,1,1,64).cpu()
        #             xx = np.arange(0,64,1)
        #     #         plt.ylim(-7, 7)
        #             ax2.plot(xx,p2[0,0,0,0],'r', label='R Channel')
        #             ax2.plot(xx,p2[0,1,0,0],'g', label='G Channel')
        #             ax2.plot(xx,p2[0,2,0,0],'b', label='B Channel')
        #             ax2.legend()
        #             ax2.set_title('Style Curve of Stage 2')
                plt.tight_layout()
                plt.legend(fontsize=20)
        #             plt.xlabel('Dimension')
        #             ax2.set_ylabel('Style Parameter Values')
        #             y_ticks_1 = np.arange(-2.5, 2.5, 0.5)
                y_ticks_2 = np.arange(0, 1.0, 0.2)
        #             ax1.set_ylabel('Style Parameter Values')
        #             ax1.set_yticks(y_ticks_1)
        #                 ax2.set_yticks(y_ticks_2)
#                 plt.show()
                plt.axis('square')
                plt.savefig('/home/ipprlab/projects/xharm/Figs/Label_analysis/' + batches["name"][0].split('.')[0] + '_'+ superCats[i] + '.pdf', dpi=200, bbox_inches='tight')
# Out:
# loading validation file...
# True
# total Dataset of ABS is :  15
# train: 15 mask: 15 anno: 15
# stack: True
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-e2173007b3a4> in <module>
#      72
#      73 with torch.no_grad():
# ---> 74     for i, batches in enumerate(val_loader):
#      75         if i != 6:
#      76             continue
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     433         if self._sampler_iter is None:
#     434             self._reset()
# --> 435         data = self._next_data()
#     436         self._num_yielded += 1
#     437         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     473     def _next_data(self):
#     474         index = self._next_index()  # may raise StopIteration
# --> 475         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     476         if self._pin_memory:
#     477             data = _utils.pin_memory.pin_memory(data)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/projects/xharm/scripts/datasets/HCOCO.py in __getitem__(self, item)
#     126                 "mask_url": self.mask[item],
#     127                 "anno_url": self.anno[item],
# --> 128                 "ori_img": self.trans(img),
#     129                 "ori_mask": self.trans(mask),
#     130                 "ori_tar": self.trans(anno),
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      65     def __call__(self, img):
#      66         for t in self.transforms:
# ---> 67             img = t(img)
#      68         return img
#      69
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/torchvision/transforms/transforms.py in forward(self, img)
#     265             PIL Image or Tensor: Rescaled image.
#     266         """
# --> 267         return F.resize(img, self.size, self.interpolation)
#     268
#     269     def __repr__(self):
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/torchvision/transforms/functional.py in resize(img, size, interpolation)
#     308     """
#     309     if not isinstance(img, torch.Tensor):
# --> 310         return F_pil.resize(img, size=size, interpolation=interpolation)
#     311
#     312     return F_t.resize(img, size=size, interpolation=interpolation)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/torchvision/transforms/functional_pil.py in resize(img, size, interpolation)
#     427             return img.resize((ow, oh), interpolation)
#     428     else:
# --> 429         return img.resize(size[::-1], interpolation)
#     430
#     431
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/PIL/Image.py in resize(self, size, resample, box, reducing_gap)
#    1933                 )
#    1934
# -> 1935         return self._new(self.im.resize(size, resample, box))
#    1936
#    1937     def reduce(self, factor, box=None):
#
# KeyboardInterrupt:

# %%
print(int('0') + 1)
# Out:
# 1
